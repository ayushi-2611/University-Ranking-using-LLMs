# %%
import pandas as pd
df = pd.read_excel("C:/Users/gupta/Python jypter notebook/Data/Excel3.xlsx")

# %%
pd.set_option('display.max_rows', None)
df.isnull().sum().sort_values(ascending=False)
# Out:
# 2022.Threeyear average                            50
# Students per Staff                                47
# Research Quality                                  38
# Career progress rank 2022-2021                    38
# 2022.Rank in 2021                                 38
# Value for money rank 2022-2021                    38
# International work mobility rank 2022-2021        38
# International course experience rank 2022-2021    38
# Satisfaction Change                               30
# Faculty Change                                    30
# Careers service Rank Stability                    27
# 2022.Delimited                                    26
# 2022.Employed at three months (%)                 26
# 2022.Aims achieved (%)                            25
# 2022.Women on board (%)                           25
# 2022.Internships (%)                              25
# 2022.Faculty with doctorates (%)                  25
# 2022.International work mobility rank             25
# ...

# %%
df.drop("2022.Threeyear average", inplace=True, axis=1)
df.drop("Students per Staff", inplace=True, axis=1)

# %%
categorical_columns = df.select_dtypes(include=['object', 'category'])
print("Categorical Columns:")
print(categorical_columns)
# Out:
# Categorical Columns:
#                                            School Name  \
# 0                              University of St Gallen
# 1                                            HEC Paris
# 2                               London Business School
# 3                                Essec Business School
# 4                                 ESCP Business School
# 5                       SDA Bocconi/Università Bocconi
# 6                   University College Dublin: Smurfit
# 7    Rotterdam School of Management, Erasmus Univer...
# 8                                   IE Business School
# 9                                Esade Business School
# 10                       Stockholm School of Economics
# 11    WU (Vienna University of Economics and Business)
# 12                              University of Mannheim
# 13                    Imperial College Business School
# 14            WHU – Otto Beisheim School of Management
# 15                               Edhec Business School
# ...

# %%
df.drop("2021.Three-year average", inplace=True, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.drop("2021.Three-year average", inplace=True, axis=1)
#       2 df['2022.Internships (%'].replace('No data §', 0, inplace=True)
#       3 df['2022.Internships (%)'] = df['2022.Internships (%)'].astype(int)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
#    5201     labels: IndexLabel | None = None,
#    (...)
#    5208     errors: IgnoreRaise = "raise",
#    5209 ) -> DataFrame | None:
#    5210     """
#    5211     Drop specified labels from rows or columns.
#    5212
#    (...)
#    5345             weight  1.0     0.8
#    5346     """
# -> 5347     return super().drop(
#    5348         labels=labels,
#    5349         axis=axis,
# ...

# %%
df.drop("2022.Internships (%)", inplace=True, axis=1)

# %%
df["binned_group"] = pd.cut(df["Rank in 2021"], bins = 10, labels=["1-10","11-20","21-30","31-40","41-50","51-60","61-70","71-80","81-90","91-100"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Rank in 2021'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ...
