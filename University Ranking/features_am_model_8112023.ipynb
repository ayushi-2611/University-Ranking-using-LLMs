# %%
import pandas as pd
df = pd.read_excel("C:/Users/gupta/Python jypter notebook/Data/Features_am_8112023.xlsx")

# %%
df.shape
# Out:
# (125, 92)

# %%
pd.set_option('display.max_rows', None)
df.isnull().sum().sort_values(ascending=False)
# Out:
# Students per Staff                                47
# Value for money rank 2020-2019                    44
# Career progress rank 2020-2019                    44
# International course experience rank 2020-2019    44
# International work mobility rank 2020-2019        44
# Career progress rank 2021-2020                    42
# International course experience rank 2021-2020    42
# International work mobility rank 2021-2020        42
# Value for money rank 2021-2020                    42
# International course experience rank 2022-2021    38
# Career progress rank 2022-2021                    38
# Value for money rank 2022-2021                    38
# International work mobility rank 2022-2021        38
# Research Quality                                  38
# 2020.Average course length (months)               35
# 2020.Salary percentage increase                   35
# 2020.Company internships (%)                      35
# 2020.International course experience rank         35
# ...

# %%
numerical_columns = df.select_dtypes(include=['number'])
print("Numerical Columns:")
print(numerical_columns)
# Out:
# Numerical Columns:
#      Google Rating  Google Number of Reviews  Research Quality  \
# 0              4.5                     217.0              81.4
# 1              4.4                     265.0              38.8
# 2              4.8                     322.0              95.4
# 3              4.4                     266.0              24.9
# 4              4.2                     104.0               NaN
# 5              4.7                     196.0              68.2
# 6              4.5                     103.0              84.0
# 7              4.5                     103.0              96.9
# 8              4.5                     195.0               NaN
# 9              4.0                     141.0               NaN
# 10             4.4                      89.0               NaN
# 11             4.6                     604.0               NaN
# 12             4.5                     374.0              90.2
# 13             4.6                      89.0               NaN
# ...

# %%
categorical_columns = df.select_dtypes(include=['object', 'category'])
print("Categorical Columns:")
print(categorical_columns)
# Out:
# Categorical Columns:
#                                            School Name  \
# 0                              University of St Gallen
# 1                                            HEC Paris
# 2                               London Business School
# 3                                Essec Business School
# 4                                 ESCP Business School
# 5                       SDA Bocconi/Università Bocconi
# 6                   University College Dublin: Smurfit
# 7    Rotterdam School of Management, Erasmus Univer...
# 8                                   IE Business School
# 9                                Esade Business School
# 10                       Stockholm School of Economics
# 11    WU (Vienna University of Economics and Business)
# 12                              University of Mannheim
# 13                    Imperial College Business School
# 14            WHU – Otto Beisheim School of Management
# 15                               Edhec Business School
# ...

# %%
df['Threeyear average 2021'].replace('-', 0, inplace=True)

# %%
df["binned_group"] = pd.cut(df["Rank in 2022"], bins = 10, labels=["1-10","11-20","21-30","31-40","41-50","51-60","61-70","71-80","81-90","91-100"])
