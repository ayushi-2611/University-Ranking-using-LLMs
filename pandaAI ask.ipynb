# %%
import pandas as pd
from pandasai import SmartDataframe

# Sample DataFrame
df = pd.DataFrame({
    "country": ["United States", "United Kingdom", "France", "Germany", "Italy", "Spain", "Canada", "Australia", "Japan", "China"],
    "gdp": [19294482071552, 2891615567872, 2411255037952, 3435817336832, 1745433788416, 1181205135360, 1607402389504, 1490967855104, 4380756541440, 14631844184064],
    "happiness_index": [6.94, 7.16, 6.66, 7.07, 6.38, 6.4, 7.23, 7.22, 5.87, 5.12]
})

# Instantiate a LLM
from pandasai.llm import OpenAI
llm = OpenAI(api_token="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")

df = SmartDataframe(df, config={"llm": llm})
df.chat('Which are the 5 happiest countries?')
# Out:
# 'Canada, Australia, United Kingdom, Germany, United States'

# %%
import pandas as pd
from pandasai import SmartDataframe

# Sample DataFrame
df = pd.read_excel("C:/Users/gupta/Python jypter notebook/Data/2022.xlsx")

# Instantiate a LLM
from pandasai.llm import OpenAI
llm = OpenAI(api_token="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")

df = SmartDataframe(df, config={"llm": llm})

# %%
df.chat('What is this dataset about?')
# Out:
# 'The dataset contains 100 rows and 26 columns. The columns are: #, School Name, Location by primary campus, Careers service rank, International board (%), International course experience rank, Internships (%), Threeyear average, Faculty with doctorates (%), International work mobility rank, Rank in 2020, Rank in 2021, Average course length (months), Overall satisfaction, Women on board (%), Female students (%), Female faculty (%), Career progress rank, Salary percentage increase, Programme name, Weighted salary (US$), Value for money rank, Employed at three months (%), International faculty (%), International students (%), Aims achieved (%).'

# %%
df.chat('what factors influence the ranking of the university')
# Out:
# 'The factors that influence the ranking of the university are: Careers service rank, International board (%), International course experience rank, Internships (%), Threeyear average, Faculty with doctorates (%), International work mobility rank, Average course length (months), Overall satisfaction, Women on board (%), Female students (%), Female faculty (%), Career progress rank, Salary percentage increase, Value for money rank, Employed at three months (%), International faculty (%), International students (%), Aims achieved (%).'

# %%
df.chat("How can I go about doing EDA for understanding the rankings of the universities")

# %%
df.chat("Can you create a metadata for the excel file I passed?")
# Out:
#     count unique                      top freq       mean        std     min  \
# 0   100.0    NaN                      NaN  NaN      50.34  29.006171     1.0
# 1     100    100  University of St Gallen    1        NaN        NaN     NaN
# 2     100     31                   France   24        NaN        NaN     NaN
# 3   100.0    NaN                      NaN  NaN       50.5  29.011492     1.0
# 4   100.0    NaN                      NaN  NaN      45.39  29.808105     0.0
# 5   100.0    NaN                      NaN  NaN      50.05  28.315458     1.0
# 6     100     29                      100   53        NaN        NaN     NaN
# 7    75.0    NaN                      NaN  NaN  44.146667  26.696843     1.0
# 8   100.0    NaN                      NaN  NaN      94.06   7.550263    62.0
# 9   100.0    NaN                      NaN  NaN      50.49  29.019845     1.0
# 10   77.0    NaN                      NaN  NaN  44.324675  26.640611     1.0
# ...

# %%
import pandas as pd
from pandasai import SmartDataframe

# Sample DataFrame
df = pd.read_excel("C:/Users/gupta/Python jypter notebook/Data/Combined_Data_181023_data_collection_output_feature_imputation.xlsx")

# Instantiate a LLM
from pandasai.llm import OpenAI
llm = OpenAI(api_token="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")

df = SmartDataframe(df, config={"llm": llm})

# %%
df.chat("Give me the  numerical columns correlated to each other with correlation greater than 0.7, please give with which column they are corelated and what is the correlation coefficient?")
# Out:
#                                         Faculty with doctorates (%) 2021  \
# Faculty with doctorates (%) 2021                                     NaN
# Female faculty (%) 2022 Change                                       NaN
# Female students (%) 2022 Change                                      NaN
# International board (%) 2022 Change                                  NaN
# International faculty (%) 2022 Change                                NaN
# International students (%) 2022 Change                               NaN
# Overall satisfaction 2021                                       0.972924
# Rank Stability                                                       NaN
# Salary percentage increase 2021                                 0.762019
# Value for money Rank Stability                                       NaN
# Value for money rank 2021                                            NaN
# Value for money rank 2022                                            NaN
# ...

# %%
df.chat("What are the ML models you will suggest to make a predictive model to predict the rank using the data")
# Out:
# 'Unfortunately, I was not able to answer your question, because of the following error:\n\nNo code found in the response\n'

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

n_cols = len(df.columns)  
n_rows = (n_cols - 1) // 4 + 1  
plt.figure(figsize=(20, 18))
for index, column in enumerate(df.drop('Rank Change 2022-2021', axis=1).columns):
    plt.subplot(n_rows, 4, index + 1)  # Adjust the grid size
    plt.scatter(x=column, y='Rank Change 2022-2021', data=df)
    plt.title(column)

plt.subplots_adjust(wspace=1.02, hspace=0.2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17360\370478751.py in ?()
#       5 n_cols = len(df.columns)
#       6 n_rows = (n_cols - 1) // 4 + 1
#       7 plt.figure(figsize=(20, 18))
#       8 numeric_columns = df.select_dtypes(include=['number'])
# ----> 9 for index, column in enumerate(df.drop('Rank Change 2022-2021', axis=1).numeric_columns):
#      10     plt.subplot(n_rows, 4, index + 1)  # Adjust the grid size
#      11     plt.scatter(x=column, y='Rank Change 2022-2021', data=df)
#      12     plt.title(column)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# ...

# %%
df.chat("Looking at above charts can you give some key insights?")
# Out:
# 'The school with the highest number of LinkedIn followers is London Business School.\nThe school with the highest Instagram engagement percentage is Leeds University Business School.\nThe school with the highest Google rating is HKUST Business School.'

# %%
df.chat("Use above Scatterplots to identify any trends, clusters, or outliers")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df.chat("Use above Scatterplots to identify any trends, clusters, or outliers")
#
# File ~\anaconda3\Lib\site-packages\pandasai\smart_dataframe\__init__.py:343, in SmartDataframe.chat(self, query, output_type)
#     322 def chat(self, query: str, output_type: Optional[str] = None):
#     323     """
#     324     Run a query on the dataframe.
#     325
#    (...)
#     341         ValueError: If the query is empty
#     342     """
# --> 343     return self.lake.chat(query, output_type)
#
# File ~\anaconda3\Lib\site-packages\pandasai\smart_datalake\__init__.py:380, in SmartDatalake.chat(self, query, output_type)
#     372     return (
#     373         "Unfortunately, I was not able to answer your question, "
#     374         "because of the following error:\n"
#     375         f"\n{exception}\n"
# ...
