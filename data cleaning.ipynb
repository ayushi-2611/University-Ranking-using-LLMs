# %%
# !pip install pandas openpyxl

# %%
import pandas as pd

# %% [markdown]
# #### exporting my excel file

# %%
df = pd.read_excel("C:/Users/gupta/OneDrive/data predictive moxeling/Data/Data/2022.xlsx")

# %% [markdown]
# #### getting to understand the file

# %%
df.head()
# Out:
#    #                                        School Name  \
# 0  1                            University of St Gallen
# 1  2                                          HEC Paris
# 2  3  Rotterdam School of Management, Erasmus Univer...
# 3  4                      Stockholm School of Economics
# 4  5                               ESCP Business School
#
#   Location by primary campus  Careers service rank  International board (%)  \
# 0                Switzerland                     1                       53
# 1                     France                    16                       83
# 2                Netherlands                    32                       12
# 3                     Sweden                     8                       43
# 4                     France                    49                       95
#
#    International course experience rank Internships (%)  Threeyear average  \
# 0                                     9             100                1.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 26 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   #                                     100 non-null    int64
#  1   School Name                           100 non-null    object
#  2   Location by primary campus            100 non-null    object
#  3   Careers service rank                  100 non-null    int64
#  4   International board (%)               100 non-null    int64
#  5   International course experience rank  100 non-null    int64
#  6   Internships (%)                       100 non-null    object
#  7   Threeyear average                     75 non-null     float64
#  8   Faculty with doctorates (%)           100 non-null    int64
#  9   International work mobility rank      100 non-null    int64
#  10  Rank in 2020                          77 non-null     float64
# ...

# %% [markdown]
# #### for summary statistics.

# %%
df.describe()
# Out:
#                 #  Careers service rank  International board (%)  \
# count  100.000000            100.000000               100.000000
# mean    50.340000             50.500000                45.390000
# std     29.006171             29.011492                29.808105
# min      1.000000              1.000000                 0.000000
# 25%     25.750000             25.750000                21.000000
# 50%     50.000000             50.500000                42.500000
# 75%     74.500000             75.250000                67.250000
# max    100.000000            100.000000               100.000000
#
#        International course experience rank  Internships (%)  \
# count                            100.000000        99.000000
# mean                              50.050000        68.505051
# std                               28.315458        41.018755
# min                                1.000000         0.000000
# 25%                               25.750000        24.000000
# ...

# %% [markdown]
# #### Handling Missing Values

# %%
df.isnull()
# Out:
#         #  School Name  Location by primary campus  Careers service rank  \
# 0   False        False                       False                 False
# 1   False        False                       False                 False
# 2   False        False                       False                 False
# 3   False        False                       False                 False
# 4   False        False                       False                 False
# ..    ...          ...                         ...                   ...
# 95  False        False                       False                 False
# 96  False        False                       False                 False
# 97  False        False                       False                 False
# 98  False        False                       False                 False
# 99  False        False                       False                 False
#
#     International board (%)  International course experience rank  \
# ...

# %% [markdown]
# Use df.dropna() to remove rows with missing values or df.fillna() to fill missing values with specific values.

# %%
df.dropna()
# Out:
#       #                                        School Name  \
# 0     1                            University of St Gallen
# 1     2                                          HEC Paris
# 2     3  Rotterdam School of Management, Erasmus Univer...
# 3     4                      Stockholm School of Economics
# 4     5                               ESCP Business School
# ..  ...                                                ...
# 86   87                  Durham University Business School
# 89   90                                DCU Business School
# 94   95                           Paris School of Business
# 97   98                    Corvinus University of Budapest
# 99  100             University of British Columbia: Sauder
#
#    Location by primary campus  Careers service rank  International board (%)  \
# 0                 Switzerland                     1                       53
# 1                      France                    16                       83
# ...

# %% [markdown]
# #### Dealing with Duplicates

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Length: 100, dtype: bool

# %%
df.drop_duplicates()
# Out:
#       #                                        School Name  \
# 0     1                            University of St Gallen
# 1     2                                          HEC Paris
# 2     3  Rotterdam School of Management, Erasmus Univer...
# 3     4                      Stockholm School of Economics
# 4     5                               ESCP Business School
# ..  ...                                                ...
# 95   96        NMIMS Mumbai, School of Business Management
# 96   97       International Management Institute New Delhi
# 97   98                    Corvinus University of Budapest
# 98   99               University of Exeter Business School
# 99  100             University of British Columbia: Sauder
#
#    Location by primary campus  Careers service rank  International board (%)  \
# 0                 Switzerland                     1                       53
# 1                      France                    16                       83
# ...

# %% [markdown]
# #### Calculate the Average Value

# %%
average_value = df['Threeyear average'].mean()

# %% [markdown]
#  Fill Missing Values using average in a column

# %%
df['Threeyear average'].fillna(average_value, inplace=True)

# %% [markdown]
# if you want to fill missing values with a default value (e.g., default_value), you can do this

# %%
default_value = 0  
df['Rank in 2020'].fillna(default_value, inplace=True)

# %%
default_value = 0  
df['Rank in 2021'].fillna(default_value, inplace=True)

# %%
df.to_excel('cleaned_data_2022.xlsx', index=False)

# %% [markdown]
# #### now reading the clean data

# %%
df = pd.read_excel('cleaned_data_2022.xlsx')

# %% [markdown]
#  function to obtain summary statistics for numeric columns

# %%
summary_stats = df.describe()

# %%
summary_stats
# Out:
#                 #  Careers service rank  International board (%)  \
# count  100.000000            100.000000               100.000000
# mean    50.340000             50.500000                45.390000
# std     29.006171             29.011492                29.808105
# min      1.000000              1.000000                 0.000000
# 25%     25.750000             25.750000                21.000000
# 50%     50.000000             50.500000                42.500000
# 75%     74.500000             75.250000                67.250000
# max    100.000000            100.000000               100.000000
#
#        International course experience rank  Threeyear average  \
# count                            100.000000         100.000000
# mean                              50.050000          44.146667
# std                               28.315458          23.081189
# min                                1.000000           1.000000
# ...

# %% [markdown]
# To get the frequency counts of categorical variables

# %%
frequency_counts = df['Location by primary campus'].value_counts()
frequency_counts
# Out:
# France             24
# UK                  8
# Germany             7
# India               7
# Belgium             5
# Switzerland         4
# Netherlands         4
# Spain               3
# Canada              3
# Italy               3
# Portugal            3
# China               3
# Ireland             3
# Sweden              3
# Russia              2
# US                  2
# Finland             2
# Poland              1
# Norway              1
# Morocco             1
# Slovenia            1
# Taiwan              1
# Singapore           1
# US/China/Spain      1
# Australia           1
# Spain/France/UK     1
# Denmark             1
# Spain/US/Taiwan     1
# Austria             1
# Czech Republic      1
# Hungary             1
# Name: Location by primary campus, dtype: int64

# %% [markdown]
# Create histograms, bar plots, or box plots to visualize the data distribution

# %%
import matplotlib.pyplot as plt

df['International board (%)'].plot(kind='hist', bins=20, title='Histogram')
plt.show()

# %% [markdown]
# #### . Correlation Analysis

# %%
correlation_matrix = df.corr()
# Out:
# C:\Users\gupta\AppData\Local\Temp\ipykernel_4596\4214245630.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# #### regression analysis

# %%
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
y = df['International course experience rank']
x = df['International board (%)']

# %% [markdown]
# Add a constant term (intercept) to the independent variable

# %%
x = sm.add_constant(x)

# %% [markdown]
# Fit a linear regression model

# %%
model = sm.OLS(y, x).fit()

# %%
Print the regression summary

# %%
print(model.summary())
# Out:
#                                      OLS Regression Results
# ...
# Dep. Variable:     International course experience rank   R-squared:                       0.122
# Model:                                              OLS   Adj. R-squared:                  0.113
# Method:                                   Least Squares   F-statistic:                     13.58
# Date:                                  Tue, 19 Sep 2023   Prob (F-statistic):           0.000375
# Time:                                          13:57:36   Log-Likelihood:                -469.24
# No. Observations:                                   100   AIC:                             942.5
# Df Residuals:                                        98   BIC:                             947.7
# Df Model:                                             1
# Covariance Type:                              nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %% [markdown]
# Scatter plot of the data

# %%
plt.scatter(df['International board (%)'], df['International course experience rank'], label='Data Points')

# %%
plt.plot(df['International board (%)'], model.predict(), color='red', label='Regression Line')

plt.xlabel('International board (%)')
plt.ylabel('International course experience rank')
plt.legend()
plt.show()
