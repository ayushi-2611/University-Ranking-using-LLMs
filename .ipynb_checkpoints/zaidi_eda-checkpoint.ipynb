# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

df = pd.read_csv("C:/Users/gupta/Python jypter notebook/School_Names.csv")

# %%
df
# Out:
#                                      School Name  Followers  QS Ranking
# 0                                      HEC Paris      290.0         1.0
# 1                        University of St Gallen      115.0         NaN
# 2                         London Business School      537.0         3.0
# 3                           ESCP Business School      184.0         NaN
# 4                          Essec Business School      190.0         2.0
# ..                                           ...        ...         ...
# 131    University of Strathclyde Business School        2.0        93.0
# 132            Nottingham Business School at NTU       21.0        90.0
# 133    University of Liverpool Management School        8.0       151.0
# 134  University of Bradford School of Management       12.0         NaN
# 135                       Brunel Business School        2.0       151.0
#
# [136 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136 entries, 0 to 135
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   School Name  136 non-null    object
#  1   Followers    102 non-null    float64
#  2   QS Ranking   94 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 3.3+ KB

# %%
from pandas_summary import DataFrameSummary

# Exclude non-numeric columns from the DataFrame
numeric_df = df.select_dtypes(include=['number'])

# Create the summary
summary = DataFrameSummary(numeric_df)
print(summary.summary())
# Out:
#               Followers QS Ranking
# count             102.0       94.0
# mean          75.137255  75.659574
# std           91.434448  49.152288
# min                 1.0        1.0
# 25%               17.25      34.25
# 50%                40.0       73.0
# 75%                96.0      115.0
# max               537.0      151.0
# counts              102         94
# uniques              76         59
# missing              34         42
# missing_perc        25%     30.88%
# types           numeric    numeric

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select numeric columns
numeric_df = df.select_dtypes(include=['number'])

# Create a correlation heatmap
plt.figure(figsize=(15, 15))
sns.heatmap(numeric_df.corr(), annot=True, cmap='PiYG')
plt.show()

# %%
import sweetviz as sv

report = sv.analyze(df)
report.show_html('report.html')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# C:\Users\gupta\anaconda3\Lib\site-packages\sweetviz\from_profiling_pandas.py:65: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(keys):
# Report report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
