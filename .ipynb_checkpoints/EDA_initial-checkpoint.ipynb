# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

from sklearn.linear_model import LinearRegression, LassoCV, RidgeCV
df = pd.read_excel("C:/Users/gupta/Python jypter notebook/Data/FT methodology data.xlsx")

# %%
df
# Out:
#      #                                        School Name  \
# 0    1                            University of St Gallen
# 1    2                                          HEC Paris
# 2    8                 University College Dublin: Smurfit
# 3    7                             London Business School
# 4    3  Rotterdam School of Management, Erasmus Univer...
# ..  ..                                                ...
# 80  91                         Lucerne School of Business
# 81  93                       ESC Clermont Business School
# 82  94                     SGH Warsaw School of Economics
# 83  96        NMIMS Mumbai, School of Business Management
# 84  97       International Management Institute New Delhi
#
#    Location by primary campus  Careers service rank  International board (%)  \
# 0                 Switzerland                     1                       53
# 1                      France                    16                       83
# ...

# %%
df.shape
# Out:
# (85, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 25 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   #                                     85 non-null     int64
#  1   School Name                           85 non-null     object
#  2   Location by primary campus            85 non-null     object
#  3   Careers service rank                  85 non-null     int64
#  4   International board (%)               85 non-null     int64
#  5   International course experience rank  85 non-null     int64
#  6   Internships (%)                       85 non-null     int64
#  7   Threeyear average                     65 non-null     float64
#  8   Faculty with doctorates (%)           85 non-null     int64
#  9   International work mobility rank      85 non-null     int64
#  10  Rank in 2020                          67 non-null     float64
# ...

# %%
df.describe()
# Out:
#                 #  Careers service rank  International board (%)  \
# count   85.000000             85.000000                85.000000
# mean    50.247059             48.188235                45.294118
# std     30.254833             28.727577                30.745818
# min      1.000000              1.000000                 0.000000
# 25%     24.000000             24.000000                20.000000
# 50%     49.000000             46.000000                43.000000
# 75%     77.000000             73.000000                68.000000
# max    100.000000            100.000000               100.000000
#
#        International course experience rank  Internships (%)  \
# count                             85.000000        85.000000
# mean                              50.788235        66.341176
# std                               28.320905        41.581118
# min                                1.000000         0.000000
# 25%                               27.000000        22.000000
# ...

# %%
df.isna().sum()
# Out:
# #                                        0
# School Name                              0
# Location by primary campus               0
# Careers service rank                     0
# International board (%)                  0
# International course experience rank     0
# Internships (%)                          0
# Threeyear average                       20
# Faculty with doctorates (%)              0
# International work mobility rank         0
# Rank in 2020                            18
# Rank in 2021                            10
# Average course length (months)           0
# Overall satisfaction                     0
# Women on board (%)                       0
# Female students (%)                      0
# Female faculty (%)                       0
# Career progress rank                     0
# Salary percentage increase               0
# Programme name                           0
# Weighted salary (US$)                    0
# Value for money rank                     0
# ...

# %%
df.fillna({'Threeyear average':1},inplace = True)
df.fillna({'Rank in 2020':1},inplace = True)
df.fillna({'Rank in 2021':1},inplace = True)

# %%
df.columns
# Out:
# Index(['#', 'School Name', 'Location by primary campus',
#        'Careers service rank', 'International board (%)',
#        'International course experience rank', 'Internships (%)',
#        'Threeyear average', 'Faculty with doctorates (%)',
#        'International work mobility rank', 'Rank in 2020', 'Rank in 2021',
#        'Average course length (months)', 'Overall satisfaction',
#        'Women on board (%)', 'Female students (%)', 'Female faculty (%)',
#        'Career progress rank', 'Salary percentage increase', 'Programme name',
#        'Weighted salary (US$)', 'Value for money rank',
#        'International faculty (%)', 'International students (%)',
#        'Aims achieved (%)'],
#       dtype='object')

# %%
plt.style.use('_mpl-gallery')                             #can see different styles frm the list by usimg print(plt.style.available)
plt.figure(figsize=(8,2))
plt.title("Top 10 countries with the Most Top-Ranked Universities ")     
plt.xlabel("Number of Top-Ranked Universities per Country")              
df["Location by primary campus"].value_counts().head(10).plot(kind="barh",color="r")      
plt.show()

# %% [markdown]
# Visualize Top 10 countries with top ranked Universities

# %%
Top_10= df.head(10)
Top_10
# Out:
#     #                                        School Name  \
# 0   1                            University of St Gallen
# 1   2                                          HEC Paris
# 2   8                 University College Dublin: Smurfit
# 3   7                             London Business School
# 4   3  Rotterdam School of Management, Erasmus Univer...
# 5   6                              Essec Business School
# 6   5                               ESCP Business School
# 7   4                      Stockholm School of Economics
# 8  12                              Edhec Business School
# 9  23                   Imperial College Business School
#
#   Location by primary campus  Careers service rank  International board (%)  \
# 0                Switzerland                     1                       53
# 1                     France                    16                       83
# 2                    Ireland                     6                       55
# ...

# %%
plt.style.use('dark_background')
plt.figure(figsize=(10,2))
plt.title("Top 20 Most Top-Ranked Universities in the world",fontsize=15)
sns.barplot(data=Top_10,x="Faculty with doctorates (%)",y="School Name",hue="Location by primary campus")           #'hue' refers to the location of the desired columns.
plt.legend()
plt.show()
# Out:
# C:\Users\gupta\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\gupta\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\gupta\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\gupta\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %%
from pandas_summary import DataFrameSummary

# Exclude non-numeric columns from the DataFrame
numeric_df = df.select_dtypes(include=['number'])

# Create the summary
summary = DataFrameSummary(numeric_df)
print(summary.summary())
# Out:
#                       # Careers service rank International board (%)  \
# count              85.0                 85.0                    85.0
# mean          50.247059            48.188235               45.294118
# std           30.254833            28.727577               30.745818
# min                 1.0                  1.0                     0.0
# 25%                24.0                 24.0                    20.0
# 50%                49.0                 46.0                    43.0
# 75%                77.0                 73.0                    68.0
# max               100.0                100.0                   100.0
# counts               85                   85                      85
# uniques              85                   85                      49
# missing               0                    0                       0
# missing_perc         0%                   0%                      0%
# types           numeric              numeric                 numeric
#
# ...

# %%
pip install sweetviz
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sweetviz as sv

report = sv.analyze(df)
report.show_html('report.html')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# C:\Users\gupta\anaconda3\Lib\site-packages\sweetviz\from_profiling_pandas.py:65: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(keys):
# C:\Users\gupta\anaconda3\Lib\site-packages\sweetviz\from_profiling_pandas.py:65: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(keys):
# C:\Users\gupta\anaconda3\Lib\site-packages\sweetviz\from_profiling_pandas.py:65: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(keys):
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select numeric columns
numeric_df = df.select_dtypes(include=['number'])

# Create a correlation heatmap
plt.figure(figsize=(15, 15))
sns.heatmap(numeric_df.corr(), annot=True, cmap='PiYG')
plt.show()
